# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="joel",
  password="jo*el!eg1",
  database="Life_Expectancy"
)
mycursor = mydb.cursor()

# %%
for x in mycursor:
    print(x)

# %%
mycursor.execute("SELECT * FROM country_data")

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (' Country', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '', '2014', '2015')
# ('Afghanistan', '55.8', '56.3', '56.8', '57.3', '57.8', '58.3', '58.8', '59.4', '59.9', '60.5', '61.0', '61.6', '62.1', '62.5', '', '63.0', '63.4')
# ('Albania', '74.0', '74.3', '74.6', '74.8', '75.0', '75.2', '75.4', '75.6', '75.9', '76.2', '76.6', '76.9', '77.3', '77.6', '', '77.8', '78.0')
# ('Algeria', '70.6', '71.1', '71.6', '72.1', '72.6', '73.1', '73.5', '73.9', '74.3', '74.6', '74.9', '75.2', '75.4', '75.7', '', '75.9', '76.1')
# ('American Samoa', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '', '..', '..')
# ('Andorra', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '', '..', '..')
# ('Angola', '46.5', '47.1', '47.7', '48.4', '49.3', '50.2', '51.1', '52.2', '53.2', '54.3', '55.4', '56.3', '57.2', '58.1', '', '58.8', '59.4')
# ...

# %%
mycursor.execute("SHOW TABLES")
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('country_data',)

# %%
mycursor.execute("SELECT country FROM country_data ")
for x in mycursor:
    print(x)
# Out:
# (' Country',)
# ('Afghanistan',)
# ('Albania',)
# ('Algeria',)
# ('American Samoa',)
# ('Andorra',)
# ('Angola',)
# ('Antigua and Barbuda',)
# ('Argentina',)
# ('Armenia',)
# ('Aruba',)
# ('Australia',)
# ('Austria',)
# ('Azerbaijan',)
# ('Bahamas, The',)
# ('Bahrain',)
# ('Bangladesh',)
# ('Barbados',)
# ('Belarus',)
# ('Belgium',)
# ('Belize',)
# ('Benin',)
# ('Bermuda',)
# ('Bhutan',)
# ('Bolivia',)
# ('Bosnia and Herzegovina',)
# ('Botswana',)
# ('Brazil',)
# ('British Virgin Islands',)
# ('Brunei Darussalam',)
# ('Bulgaria',)
# ('Burkina Faso',)
# ('Burundi',)
# ('Cabo Verde',)
# ('Cambodia',)
# ('Cameroon',)
# ('Canada',)
# ('Cayman Islands',)
# ('Central African Republic',)
# ('Chad',)
# ('Channel Islands',)
# ('Chile',)
# ('China',)
# ('Colombia',)
# ('Comoros',)
# ('Congo, Dem. Rep.',)
# ('Congo, Rep.',)
# ('Costa Rica',)
# ("Cote d'Ivoire",)
# ('Croatia',)
# ('Cuba',)
# ('Curacao',)
# ('Cyprus',)
# ('Czech Republic',)
# ('Denmark',)
# ('Djibouti',)
# ('Dominica',)
# ...

# %%
mycursor.execute("SELECT * FROM country_data LIMIT 2,5")
for x in mycursor:
    print(x)
# Out:
# ('Albania', '74.0', '74.3', '74.6', '74.8', '75.0', '75.2', '75.4', '75.6', '75.9', '76.2', '76.6', '76.9', '77.3', '77.6', '', '77.8', '78.0')
# ('Algeria', '70.6', '71.1', '71.6', '72.1', '72.6', '73.1', '73.5', '73.9', '74.3', '74.6', '74.9', '75.2', '75.4', '75.7', '', '75.9', '76.1')
# ('American Samoa', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '', '..', '..')
# ('Andorra', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '..', '', '..', '..')
# ('Angola', '46.5', '47.1', '47.7', '48.4', '49.3', '50.2', '51.1', '52.2', '53.2', '54.3', '55.4', '56.3', '57.2', '58.1', '', '58.8', '59.4')

# %%
mycursor.execute("SELECT * FROM country_data WHERE country = 'Nigeria'")
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('Nigeria', '46.3', '46.5', '46.8', '47.2', '47.7', '48.3', '48.8', '49.4', '49.9', '50.4', '50.9', '51.3', '51.8', '52.2', '', '52.7', '53.1')

# %%
mycursor.execute("SELECT * FROM country_data")

myresult = mycursor.fetchone()

print(myresult)
# Out:
# (' Country', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '', '2014', '2015')

# %%
mycursor.execute("SELECT * FROM country_data WHERE country = 'Angola'")
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('Angola', '46.5', '47.1', '47.7', '48.4', '49.3', '50.2', '51.1', '52.2', '53.2', '54.3', '55.4', '56.3', '57.2', '58.1', '', '58.8', '59.4')
